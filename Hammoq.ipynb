# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinav1103mech/Machine-Learning/blob/master/Hammoq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Read The image
image = cv2.imread('/content/drive/MyDrive/Hammoq.jpeg')
plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
plt.show()

# %%
image.shape
# Out:
# (600, 600, 3)

# %%
image[0][0]
# Out:
# array([129, 153, 183], dtype=uint8)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
print("Original Image:")
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# Original Image:

# %%
gray.shape
# Out:
# (600, 600)

# %%
data = np.array(gray)
flattened = data.flatten()
flattened.shape
# Out:
# (360000,)

# %%
flattened
# Out:
# array([159, 161, 153, ..., 161, 182, 179], dtype=uint8)

# %%
mat_y = np.array([[ -1, -2, -1], 
                   [ 0, 0, 0], 
                   [ 1, 2, 1]])
mat_x = np.array([[ -1, 0, 1], 
                   [ 0, 0, 0], 
                   [ 1, 2, 1]])
  
filtered_image = cv2.filter2D(gray, -1, mat_y)
plt.imshow(filtered_image, cmap='gray')
filtered_image = cv2.filter2D(gray, -1, mat_x)
plt.imshow(filtered_image, cmap='gray')
plt.axis('off')
plt.show()
